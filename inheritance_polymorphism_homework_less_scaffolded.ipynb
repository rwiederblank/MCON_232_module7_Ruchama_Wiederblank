# %% [markdown]
# <a href="https://colab.research.google.com/github/rwiederblank/MCON_232_module7_Ruchama_Wiederblank/blob/main/inheritance_polymorphism_homework_less_scaffolded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework: Inheritance and Polymorphism in Python
#
# **Estimated time for a fast worker:** about 90 minutes
#
# ## Purpose
# This homework is designed to help you practice:
#
# - building a parent class
# - creating child classes through inheritance
# - overriding methods
# - using polymorphism with a collection of related objects
#
# ## Directions
# Write your code in the code cells provided.
#
# This assignment is **less scaffolded** than an in-class lab. You are expected to design the classes and methods based on the problem descriptions below.
#
# You may review your notes, class examples, and your previous work.
#
# ## Requirements
# - Use clear class and method names.
# - Use inheritance properly.
# - Override methods where appropriate.
# - Demonstrate polymorphism by storing child objects together and using them through a shared interface.
# - Include comments where they help explain your thinking.
#
# ## Support
# You are not being given the full design step-by-step, but you should use these ideas to guide your thinking:
#
# - A **parent class** should hold the information and behaviors that multiple child classes share.
# - A **child class** can reuse the parent constructor and can also replace behavior by overriding methods.
# - **Polymorphism** means different child objects can respond to the same method call in their own way.

# %% [markdown]
# ## Problem 1: Build an Animal Hierarchy
#
# Create a parent class named `Animal`.
#
# ### The `Animal` class must:
# - store a name
# - store an age
# - include a method named `speak()` that returns a general animal sound
# - include a method named `move()` that returns a general description of movement
# - include a method named `describe()` that returns a short sentence about the animal
#
# Then create these child classes:
#
# - `Dog`
# - `Cat`
# - `Rabbit`
#
# ### Child class requirements
# Each child class must:
# - inherit from `Animal`
# - use the parent constructor appropriately
# - override `speak()`
# - override `move()`
#
# ### After creating your classes
# Create one object of each child class and demonstrate that:
# - each object stores its own data
# - each object gives a different result for `speak()`
# - each object gives a different result for `move()`
# - `describe()` works for each object

# %%
class Animal:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def speak(self):
    return "growl"

  def mover(self):
    return "walk"

  def describe(self):
    return f"This animal {self.name} is {self.age} years old"

class Dog(Animal):
  def speak(self):
    return f"{self.name} says: bow wow!"

  def move(self):
    return f"{self.name} bounds"

class Rabbit(Animal):

  def speak(self):
    return f"{self.name} says: squeak"

  def move(self):
    return f"{self.name} hops"

class Cat(Animal):

  def speak(self):
    return f"{self.name} says: meow!"

  def move(self):
    return f"{self.name} glides"


dog = Dog("Luna", 5)
rabbit = Rabbit("Hop", 77)
cat = Cat("Coconut", 2)

print(dog.describe())
print(dog.speak())
print(dog.move())

print(rabbit.describe())
print(rabbit.speak())
print(rabbit.move())

print(cat.describe())
print(cat.speak())
print(cat.move())
# Out:
# This animal Luna is 5 years old
# Luna says: bow wow!
# Luna bounds
# This animal Hop is 77 years old
# Hop says: squeak
# Hop hops
# This animal Coconut is 2 years old
# Coconut says: meow!
# Coconut glides

# %% [markdown]
# ### Light checkpoint for Problem 1
# Before moving on, make sure:
# - your parent class is actually being inherited
# - the child classes do not duplicate unnecessary code from the parent
# - method overriding is visible in your output

# %% [markdown]
# ## Problem 2: Build a Vehicle Hierarchy
#
# Create a parent class named `Vehicle`.
#
# ### The `Vehicle` class must:
# - store a brand
# - store a speed
# - include a method named `move()` that returns a general statement about transportation
# - include a method named `sound_horn()` that returns a general horn sound
# - include a method named `describe()` that returns a short sentence about the vehicle
#
# Then create these child classes:
#
# - `Car`
# - `Truck`
# - `Motorcycle`
#
# ### Child class requirements
# Each child class must:
# - inherit from `Vehicle`
# - use the parent constructor appropriately
# - override `move()`
# - override `sound_horn()`
#
# ### After creating your classes
# Create one object of each child class and demonstrate that:
# - each object stores its own data
# - each object gives a different result for `move()`
# - each object gives a different result for `sound_horn()`
# - `describe()` works for each object

# %%
class Vehicle:
  def __init__(self, brand, speed):
    self.brand = brand
    self.speed = speed

  def move(self):
    return "this vehicle is moving"

  def sound_horn(self):
    return "beep"

  def describe(self):
    return f"This {self.brand} vehicle is moving at {self.speed} mph"

class Car(Vehicle):
  def move(self):
    return "this car is moving"

  def sound_horn(self):
    return "BEEP"

class Truck(Vehicle):
  def move(self):
    return "this truck is moving"

  def sound_horn(self):
    return "BEEP BEEP BEEP!!!"

class Motorcycle(Vehicle):
  def move(self):
    return "this truck is moving"

  def sound_horn(self):
    return "BEEEEEEEEEEEEEEEEEEEEEP!!"


car = Car("toyota", 78)
truck = Truck("ford", 27)
motorcycle = Motorcycle("mazda", 122)
print(car.describe())
print(truck.describe())
print(motorcycle.describe())
print(car.move())
print(truck.move())
print(motorcycle.move())
print(car.sound_horn())
print(truck.sound_horn())
print(motorcycle.sound_horn())
# Out:
# This toyota vehicle is moving at 78 mph
# This ford vehicle is moving at 27 mph
# This mazda vehicle is moving at 122 mph
# this car is moving
# this truck is moving
# this truck is moving
# BEEP
# BEEP BEEP BEEP!!!
# BEEEEEEEEEEEEEEEEEEEEEP!!

# %% [markdown]
# ## Problem 3: Demonstrate Polymorphism with Animals
#
# Using your `Dog`, `Cat`, and `Rabbit` classes:
#
# 1. Create a list that stores multiple animal objects together.
# 2. Use a loop to go through the list.
# 3. For each object, call the **same methods** and show that the results differ depending on the object.
#
# ### Required methods to call in the loop
# - `speak()`
# - `move()`
# - `describe()`
#
# ## Goal
# Your output should clearly demonstrate that the program can treat all of the child objects as `Animal` objects, while each one still behaves in its own way.

# %%
c1 = Cat("Clover", 7)
c2 = Cat("Nemo", 17)
c3 = Cat("Hector", 77)
r1 = Rabbit("Norman", 12)
r2 = Rabbit("Steve", 123)
r3 = Rabbit("Tom", 1)
d1 = Dog("Frank", 5)
d2 = Dog("Sam", 44)
d3 = Dog("Gladys", 3)
animals = [c1, r1, d1, c2, r2, d2, c3, r3, d3]
for animal in animals:
  print(animal.describe())
  print(animal.move())
  print(animal.speak())
  print()
# Out:
# This animal Clover is 7 years old
# Clover glides
# Clover says: meow!
#
# This animal Norman is 12 years old
# Norman hops
# Norman says: squeak
#
# This animal Frank is 5 years old
# Frank bounds
# Frank says: bow wow!
#
# This animal Nemo is 17 years old
# Nemo glides
# Nemo says: meow!
#
# This animal Steve is 123 years old
# Steve hops
# Steve says: squeak
#
# This animal Sam is 44 years old
# Sam bounds
# Sam says: bow wow!
#
# This animal Hector is 77 years old
# Hector glides
# Hector says: meow!
#
# This animal Tom is 1 years old
# Tom hops
# Tom says: squeak
#
# This animal Gladys is 3 years old
# Gladys bounds
# Gladys says: bow wow!

# %% [markdown]
# ## Problem 4: Demonstrate Polymorphism with Vehicles
#
# Using your `Car`, `Truck`, and `Motorcycle` classes:
#
# 1. Create a list that stores multiple vehicle objects together.
# 2. Use a loop to go through the list.
# 3. For each object, call the **same methods** and show that the results differ depending on the object.
#
# ### Required methods to call in the loop
# - `move()`
# - `sound_horn()`
# - `describe()`
#
# ## Goal
# Your output should clearly demonstrate polymorphism in the vehicle family.

# %%
c1 = Car("toyota", 23)
c2 = Car("honda", 34)
t1 = Truck("ford", 67)
t2 = Truck("jeep", 78)
m1 =  Motorcycle("mazda", 89)
m2 = Motorcycle("BMW", 33)
vehicles = [c1, t1, m1, c2, t2, m2]
for vehicle in vehicles:
  print(vehicle.describe())
  print(vehicle.move())
  print(vehicle.sound_horn())
  print()
# Out:
# This toyota vehicle is moving at 23 mph
# this car is moving
# BEEP
#
# This ford vehicle is moving at 67 mph
# this truck is moving
# BEEP BEEP BEEP!!!
#
# This mazda vehicle is moving at 89 mph
# this truck is moving
# BEEEEEEEEEEEEEEEEEEEEEP!!
#
# This honda vehicle is moving at 34 mph
# this car is moving
# BEEP
#
# This jeep vehicle is moving at 78 mph
# this truck is moving
# BEEP BEEP BEEP!!!
#
# This BMW vehicle is moving at 33 mph
# this truck is moving
# BEEEEEEEEEEEEEEEEEEEEEP!!

# %% [markdown]
# ## Problem 5: Mixed Reflection
#
# Answer the following in complete sentences:
#
# 1. What is the advantage of placing shared data and behavior in a parent class?
# 2. What does it mean for a child class to override a method?
# 3. In your own words, what is polymorphism?
# 4. In this homework, how did your loops demonstrate polymorphism?

# %% [markdown]
# 1. The advantage of placing shared data in the parent class is that it avoids repetative code. If it is needed is child classes and you would write it in every single one, there would be a lot of unnecessary code. If it is written in the parent class it is written one, and all the children can still access it.
# 2. A child class can override the method in a parent class by writing a new method with the same name as a method in the parent class. When the child class is called using that method, it will accsess that method from the child class and not the one written in the parent class with the same name.
# 3. Polymorphism is about how different classes can share method names, but each class will implement the methods differently.
# 5. The loops demonstrated this because when the methods were called on each item in the list, different results were printed. You didn't have to specify if it was a Dog or a Cat or a Rabbit, you just called the method on the object and got a result based on what type the object was.

# %%
# Write your reflection answers here.

# %% [markdown]
# ## Optional Support Reminders
#
# Use these only if you get stuck:
#
# - Ask yourself what all animals have in common before writing the parent class.
# - Ask yourself what all vehicles have in common before writing the parent class.
# - If several child classes repeat the same constructor code, consider whether `super()` should be used.
# - If all objects in a list can respond to the same method name, that is often a sign of polymorphism.

# %%
# Write your extra credit here.

# %% [markdown]
# ## Submission Checklist
#
# Before you submit, make sure:
# - all required classes are present
# - inheritance is used correctly
# - overridden methods actually behave differently
# - polymorphism is shown with loops and lists
# - your notebook runs from top to bottom without errors
